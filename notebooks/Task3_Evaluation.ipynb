# %% [markdown]
# Task3_Evaluation.ipynb

# %%
from src.rag_pipeline import answer_question

questions = [
    "Why are people unhappy with credit cards?",
    "What complaints do customers have about personal loans?",
    "Are there issues around savings account access?"
]

evaluations = []
for q in questions:
    ans, sources = answer_question(q)
    evaluations.append({
        "Question": q,
        "Answer": ans,
        "Top Source": sources[0] if sources else "",
        "Quality (1-5)": None
    })

import pandas as pd
pd.DataFrame(evaluations)
